# %%
import codecs

# %%
import numpy as np
from PIL import Image

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
from textblob import TextBlob

# %%
f = codecs.open("./anti-meridian-lyrics.txt", 'r')

# %%
text = f.read()

# %%
clean_text = text.replace('um','').replace('uh','')
#.lower().replace('god','God').replace(
#    'combat chuck','Combat Chuck').replace('america','America')

# %%
album_coloring = np.array(Image.open('anti-meridian-cover.png'))
image_colors = ImageColorGenerator(album_coloring)
wordcloud = WordCloud(
    background_color=None, #"#00adef",
    mode="RGBA",
    width=2560,
    height=2560,
    mask=album_coloring,
    font_path='./Orbitron-Regular.ttf',
    collocations=False,
    normalize_plurals=False,
    prefer_horizontal=0.9999,
    stopwords=STOPWORDS).generate(clean_text).recolor(color_func=image_colors)
wordcloud.to_file('anti-meridian-wordcloud.tiff')

plt.figure(figsize=(16,16))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
#plt.figure()
# Out:
# (-0.5, 2559.5, 2559.5, -0.5)

# %%
analysis = TextBlob(clean_text)
print ('{} words'.format(len(analysis.words)))
print ('')
print ('polarity: {}'.format(analysis.sentiment.polarity))
print ('subjectivity: {}'.format(analysis.sentiment.subjectivity))
# Out:
# 4733 words
#
# polarity: 0.05366809760960181
# subjectivity: 0.48007221036468906
