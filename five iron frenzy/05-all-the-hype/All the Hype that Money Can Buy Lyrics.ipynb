# %%
import codecs

# %%
f = codecs.open("hype-lyrics.txt", 'r')

# %%
text = f.read()

# %%
import numpy as np
from PIL import Image

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
import matplotlib.image as mpimg

# %%
clean_text = text
#.upper()
#.replace('CENSORED','')
#.lower().replace('god','God').replace('jesus','Jesus')

# %%
album_coloring = np.array(Image.open('hype-cover.png'))
image_colors = ImageColorGenerator(album_coloring)
wordcloud = WordCloud(
    background_color=None, #"#f7920e",
    mode="RGBA",
    width=2560,
    height=2560,
    mask=album_coloring,
    font_path='Lora-Regular.ttf',
    collocations=False,
    prefer_horizontal=0.99,
    stopwords=STOPWORDS).generate(clean_text).recolor(color_func=image_colors)
wordcloud.to_file('hype-wordcloud.tiff')

#img=mpimg.imread('hype-cover-border.png')
#plt.imshow(img)
plt.figure(figsize=(16,16))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.figure()

# %%
release_date = "April 25, 2000"

# %%
from textblob import TextBlob
analysis = TextBlob(clean_text)
print ('{} words'.format(len(analysis.words)))
print ('')
print ('polarity: {}'.format(analysis.sentiment.polarity))
print ('subjectivity: {}'.format(analysis.sentiment.subjectivity))
# Out:
# 3256 words
#
# polarity: 0.05543843958591766
# subjectivity: 0.5849551812709717
