# %%
import codecs

# %%
import numpy as np
from PIL import Image

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
import matplotlib.image as mpimg

# %%
f = codecs.open("boogaloo-lyrics.txt", 'r')
text = f.read()

# %%
clean_text = text
#.upper()
#.replace('CENSORED','')
#.lower().replace('god','God').replace('jesus','Jesus')

# %%
album_coloring = np.array(Image.open('boogaloo-cover.png'))
image_colors = ImageColorGenerator(album_coloring)
wordcloud = WordCloud(
    background_color= None, #"#3c3d39", #"#595b55", #'white', #
    mode="RGBA", 
    width=2560,
    height=2560,
    mask=album_coloring,
    font_path='Lato-Light.ttf',
    collocations=False,
    prefer_horizontal=0.99,
    stopwords=STOPWORDS,
    normalize_plurals=False).generate(clean_text).recolor(color_func=image_colors)
wordcloud.to_file('boogaloo-wordcloud.tiff')

#img=mpimg.imread('hype-cover-border.png')
#plt.imshow(img)
plt.figure(figsize=(16,16))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
#plt.figure()
# Out:
# (-0.5, 2559.5, 2559.5, -0.5)

# %%
wordcloud.words_
# Out:
# {'Christ': 0.18181818181818182,
#  'Crazy': 0.18181818181818182,
#  'Horse': 0.18181818181818182,
#  'Jesus': 0.3181818181818182,
#  'Juggernaut': 0.7727272727272727,
#  'King': 0.09090909090909091,
#  'Love': 0.22727272727272727,
#  'Peter': 0.09090909090909091,
#  'Son': 0.09090909090909091,
#  'Spartan': 0.13636363636363635,
#  'across': 0.13636363636363635,
#  'actions': 0.13636363636363635,
#  'along': 0.09090909090909091,
#  'always': 0.18181818181818182,
#  'angel': 0.13636363636363635,
#  'another': 0.13636363636363635,
#  'anything': 0.18181818181818182,
#  'asleep': 0.09090909090909091,
#  'away': 0.5,
#  'awesome': 0.09090909090909091,
#  'back': 0.09090909090909091,
#  'beautiful': 0.13636363636363635,
#  'become': 0.09090909090909091,
#  'behind': 0.22727272727272727,
#  'believe': 0.13636363636363635,
#  'bells': 0.22727272727272727,
#  'beneath': 0.2727272727272727,
#  'better': 0.45454545454545453,
#  'blessed': 0.22727272727272727,
#  'blind': 0.09090909090909091,
#  'blow': 0.09090909090909091,
#  'blue': 0.3181818181818182,
#  'brand': 0.13636363636363635,
#  'break': 0.09090909090909091,
#  'breath': 0.09090909090909091,
#  'broken': 0.13636363636363635,
#  'brushed': 0.13636363636363635,
#  'burden': 0.09090909090909091,
#  'burning': 0.09090909090909091,
#  'cause': 0.13636363636363635,
#  'circling': 0.13636363636363635,
#  'close': 0.18181818181818182,
#  'club': 0.09090909090909091,
#  'cold': 0.09090909090909091,
#  'comes': 0.18181818181818182,
#  'da': 0.09090909090909091,
#  'dark': 0.13636363636363635,
#  'day': 0.5909090909090909,
#  'death': 0.09090909090909091,
#  'deep': 0.13636363636363635,
#  'died': 0.09090909090909091,
#  'distant': 0.09090909090909091,
#  'dollar': 0.09090909090909091,
#  'dream': 0.09090909090909091,
#  'dreamers': 0.09090909090909091,
#  'endure': 0.18181818181818182,
#  'endures': 0.09090909090909091,
#  'eulogy': 0.36363636363636365,
#  'even': 0.09090909090909091,
#  'everyone': 0.13636363636363635,
#  'everything': 0.2727272727272727,
#  'ex': 0.2727272727272727,
#  'eyes': 0.4090909090909091,
#  'failed': 0.09090909090909091,
#  'far': 1.0,
#  'farsighted': 0.6818181818181818,
#  'felt': 0.18181818181818182,
#  'fine': 0.18181818181818182,
#  'fixing': 0.13636363636363635,
#  'found': 0.09090909090909091,
#  'free': 0.22727272727272727,
#  'freedom': 0.18181818181818182,
#  'full': 0.13636363636363635,
#  'getting': 0.09090909090909091,
#  'girl': 0.22727272727272727,
#  'girlfriend': 0.2727272727272727,
#  'giving': 0.5,
#  'glassy': 0.18181818181818182,
#  'glorious': 0.13636363636363635,
#  'go': 0.09090909090909091,
#  'goes': 0.13636363636363635,
#  'going': 0.18181818181818182,
#  'gone': 0.13636363636363635,
#  'good': 0.2727272727272727,
#  'goodbye': 0.36363636363636365,
#  'got': 0.13636363636363635,
#  'gotta': 0.09090909090909091,
#  'handle': 0.36363636363636365,
#  'hear': 0.6363636363636364,
#  'heart': 0.36363636363636365,
#  'heavens': 0.13636363636363635,
#  'hello': 0.18181818181818182,
#  'hi': 0.09090909090909091,
#  'hollow': 0.18181818181818182,
#  'hope': 0.18181818181818182,
#  'huh': 0.09090909090909091,
#  'hurts': 0.09090909090909091,
#  'icy': 0.09090909090909091,
#  'innocence': 0.18181818181818182,
#  'kick': 0.13636363636363635,
#  'kill': 0.22727272727272727,
#  'killed': 0.18181818181818182,
#  'killing': 0.09090909090909091,
#  'kiss': 0.09090909090909091,
#  'know': 0.3181818181818182,
#  'last': 0.13636363636363635,
#  'leaving': 0.13636363636363635,
#  'left': 0.13636363636363635,
#  'lies': 0.45454545454545453,
#  'life': 0.36363636363636365,
#  'light': 0.09090909090909091,
#  'likelihood': 0.13636363636363635,
#  'live': 0.18181818181818182,
#  'look': 0.13636363636363635,
#  'looked': 0.09090909090909091,
#  'lost': 0.22727272727272727,
#  'luminous': 0.13636363636363635,
#  'made': 0.22727272727272727,
#  'massive': 0.09090909090909091,
#  'may': 0.18181818181818182,
#  'maybe': 0.18181818181818182,
#  'mixes': 0.13636363636363635,
#  'na': 0.7272727272727273,
#  'nation': 0.18181818181818182,
#  'nets': 0.09090909090909091,
#  'never': 0.36363636363636365,
#  'new': 0.2727272727272727,
#  'night': 0.09090909090909091,
#  'now': 0.3181818181818182,
#  'oh': 0.09090909090909091,
#  'one': 0.5,
#  'open': 0.13636363636363635,
#  'painted': 0.13636363636363635,
#  'passed': 0.13636363636363635,
#  'people': 0.09090909090909091,
#  'piece': 0.13636363636363635,
#  'plan': 0.3181818181818182,
#  'pre': 0.2727272727272727,
#  'prices': 0.13636363636363635,
#  'pride': 0.18181818181818182,
#  'reach': 0.09090909090909091,
#  'remember': 0.09090909090909091,
#  'remorse': 0.18181818181818182,
#  'revolution': 0.18181818181818182,
#  'ringing': 0.22727272727272727,
#  'rise': 0.09090909090909091,
#  'rockets': 0.09090909090909091,
#  'said': 0.18181818181818182,
#  'save': 0.13636363636363635,
#  'saw': 0.18181818181818182,
#  'say': 0.2727272727272727,
#  'sayonara': 0.22727272727272727,
#  'sea': 0.18181818181818182,
#  'see': 0.8636363636363636,
#  'shows': 0.18181818181818182,
#  'singing': 0.2727272727272727,
#  'sink': 0.22727272727272727,
#  'sleep': 0.13636363636363635,
#  'smell': 0.09090909090909091,
#  'something': 0.22727272727272727,
#  'song': 0.3181818181818182,
#  'soon': 0.09090909090909091,
#  'sound': 0.13636363636363635,
#  'span': 0.09090909090909091,
#  'steal': 0.18181818181818182,
#  'still': 0.3181818181818182,
#  'strong': 0.18181818181818182,
#  'sure': 0.13636363636363635,
#  'swallow': 0.13636363636363635,
#  'swim': 0.18181818181818182,
#  'swing': 0.09090909090909091,
#  'take': 0.09090909090909091,
#  'tear': 0.09090909090909091,
#  'tell': 0.13636363636363635,
#  'thing': 0.18181818181818182,
#  'things': 0.5,
#  'think': 0.18181818181818182,
#  'tight': 0.22727272727272727,
#  'tired': 0.22727272727272727,
#  'tonight': 0.13636363636363635,
#  'true': 0.09090909090909091,
#  'truth': 0.2727272727272727,
#  'two': 0.13636363636363635,
#  'uh': 0.13636363636363635,
#  'um': 0.13636363636363635,
#  'us': 0.22727272727272727,
#  'voices': 0.2727272727272727,
#  'vultures': 0.18181818181818182,
#  'want': 0.13636363636363635,
#  'watch': 0.3181818181818182,
#  'wave': 0.13636363636363635,
#  'way': 0.2727272727272727,
#  'weak': 0.18181818181818182,
#  'welcome': 0.3181818181818182,
#  'will': 0.7727272727272727,
#  'wings': 0.13636363636363635,
#  'world': 0.13636363636363635,
#  'write': 0.36363636363636365,
#  'wrong': 0.09090909090909091,
#  'yeah': 0.36363636363636365}
