# %%
import codecs

# %%
import numpy as np
from PIL import Image

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
import matplotlib.image as mpimg

# %%
f = codecs.open("live-proof-lyrics.txt", 'r')
text = f.read()

# %%
clean_text = text
#.upper()
#.replace('CENSORED','')
#.lower().replace('god','God').replace('jesus','Jesus')

# %%
album_coloring = np.array(Image.open('live-proof-cover.png'))
image_colors = ImageColorGenerator(album_coloring)
wordcloud = WordCloud(
    background_color="#5e4951",
    width=2560,
    height=2560,
    mask=album_coloring,
    font_path='Lora-Regular.ttf',
    collocations=False,
    stopwords=STOPWORDS).generate(clean_text).recolor(color_func=image_colors)
wordcloud.to_file('live-proof-wordcloud.tiff')

#img=mpimg.imread('hype-cover-border.png')
#plt.imshow(img)
plt.figure(figsize=(16,16))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# %%
from textblob import TextBlob
analysis = TextBlob(clean_text)
print ('{} words'.format(len(analysis.words)))
print ('')
print ('polarity: {}'.format(analysis.sentiment.polarity))
print ('subjectivity: {}'.format(analysis.sentiment.subjectivity))
# Out:
# 6139 words
#
# polarity: 0.09854341776117254
# subjectivity: 0.5122590095679269
